# %% [markdown]
# # UNIDAD 2

# %% [markdown]
# # Pandas
# Es una liberia que se utilizada para manipulación de infromación.
# - Funciones: analizar, limpiar, explorar y manipular
# - Pandas = Panel Data & Python Data Analysis
#
# **¿Porque utilizar Panda?
# - Permite en análisis en grandes volumenes de datos basandose en teoria estadisitica.
# - Permite limpiar los datasets para hacerlos manipulables
#
# **Panda se puede eliminar información no relevante, valores corruptos, sin valor o null. A estos se le llama Limpieza de datos.

# %%
import pandas

# %%
dataset = {"alu": ["Luisa", "Wendy", "Mary"], "num" : [3,1,2]} #diccionario
#type(dataset)
var = pandas.DataFrame(dataset)
#type(var)
print(var)
# Out:
#      alu  num
# 0  Luisa    3
# 1  Wendy    1
# 2   Mary    2

# %%
type(dataset)
# Out:
# dict

# %%
type(var)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd

# %%
dataset = {"alu": ["Luisa", "Wendy", "Mary"], "num" : [3,1,2]}
var = pd.DataFrame(dataset)
print(var)
# Out:
#      alu  num
# 0  Luisa    3
# 1  Wendy    1
# 2   Mary    2

# %%
#Series: arreglo unidimensional
nombres = ["Luisa", "Wendy", "Mary"]
var = pd.Series(nombres)
#type(var)
print(var)
# Out:
# 0    Luisa
# 1    Wendy
# 2     Mary
# dtype: object

# %%
type(var)
# Out:
# pandas.core.series.Series

# %%
print(var[1])
# Out:
# Wendy

# %%
#Indexado Series
nombres = ["Luisa", "Wendy", "Mary"]
var = pd.Series(nombres, index=[3, 1, 3])
var = pd.Series(nombres, index=["i", "j", "z"])
print(var)
# Out:
# i    Luisa
# j    Wendy
# z     Mary
# dtype: object

# %%
print(var["i"])
# Out:
# Luisa

# %%
#Analizando la informacion
ruta = "C:\\Users\\Dell\\Documents\\Tec Laguna\\2021(Ago-Dic)\\Big Data\\Python\\"
df = pd.read_csv(ruta+"titanic.csv")
print(df.head(5))
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print(df.tail()) #Ultimos 5
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB
# None

# %%
#Fase 1 limpieza de datos: datos vacios, duplicados, datos y formados equivocados
#revisar la informacion df
#Datos vacios - eliminar renglon
df_notNan = df.dropna() #sobre el DF original df.dropna(inplace= True)
#print(df_notNan.toString())
print(df_notNan.tail())
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True

# %%
print(df_notNan.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182 entries, 1 to 889
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     182 non-null    int64
#  1   pclass       182 non-null    int64
#  2   sex          182 non-null    object
#  3   age          182 non-null    float64
#  4   sibsp        182 non-null    int64
#  5   parch        182 non-null    int64
#  6   fare         182 non-null    float64
#  7   embarked     182 non-null    object
#  8   class        182 non-null    object
#  9   who          182 non-null    object
#  10  adult_male   182 non-null    bool
#  11  deck         182 non-null    object
#  12  embark_town  182 non-null    object
#  13  alive        182 non-null    object
#  14  alone        182 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 20.3+ KB
# None

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Rellena valores vacios
#fillna() reemplaza la celcda vacias con un valor
df.fillna(-1, inplace=True)

# %%
#Se volvio a cargar los datos
ruta = "C:\\Users\\Dell\\Documents\\Tec Laguna\\2022 (Enero-Junio)\\Big Data\\Jupyter\\"
df = pd.read_csv(ruta+"titanic.csv")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Seleccionado columnas
df["age"].fillna(-1, inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  -1.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Remplazando los datos o celdas vacias con la media
#Media promedio de una serie de valores
m = df["age"].mean()
df["age"].fillna(m, inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Mediana : valor medio de una serie de valores ordenados
m = df["age"].median()
df["age"].fillna(m, inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Moda: valor mas popular de una serie de valores
m = df["age"].mode()[0]
#print(m)
#df["age"].fillana(m, inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ruta = "C:\\Users\\Dell\\Documents\\Tec Laguna\\2022 (Enero-Junio)\\Big Data\\Jupyter\\"
df = pd.read_csv(ruta+"titanic.csv")

# %%
#Datos equivocados
#titanic : clases: 1, 2, 3 -- valores permitidios. Valores equivocados: 0, 4 ,5
#Para modificar un registro: registro 1
#df.loc[1, "pclasss"] = 3
#Para modificar todas las columnas
for i in df.index:
    if df.loc[i, "pclass"] > 3 or df.loc[i, "pclass"] < 1:
           if df.loc[i, "class"] == "Third":
            df.loc[i, "class"] = 3
    elif df.loc[i,"class"] == "Second":
        df.loc[i, "class"] = 2
    elif df.loc[i, "class"] == "First":
        df.loc[i, "pclass"] = 1

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ruta = "C:\\Users\\Dell\\Documents\\Tec Laguna\\2022 (Enero-Junio)\\Big Data\\Jupyter\\"
df = pd.read_csv(ruta+"titanic.csv")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Para borrar datos equivocados y eliminar el reglon completos
for i in df.index:
    if df.loc[i, "age"]< 5.0:
        print(i)
        df.drop(i, inplace = True)
# Out:
# 7
# 10
# 16
# 43
# 63
# 78
# 119
# 164
# 171
# 172
# 183
# 184
# 193
# 205
# 261
# 297
# 305
# 340
# 348
# 374
# 381
# 386
# 407
# 445
# 469
# 479
# 530
# 618
# 642
# 644
# 691
# 750
# 755
# 788
# 803
# 824
# 827
# 831
# 850
# 869

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 851, dtype: bool

# %%
#Para eliminar duplicados
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Fase 2. Encontrar relaciones en la información(correlacionar)
#Metodo corr(): calcula la realacion entre columnas
#Valroes -1.0 a 1.0
#Relaciones perfecta: 1.0000, Buena relacion: 0.90000
#Mala relacion: 0.000291 -- significa
df.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.346045 -0.033866 -0.018489  0.045363  0.261963
# pclass     -0.346045  1.000000 -0.376185  0.050493  0.024573 -0.547617
# age        -0.033866 -0.376185  1.000000 -0.226882 -0.085736  0.098426
# sibsp      -0.018489  0.050493 -0.226882  1.000000  0.356918  0.152367
# parch       0.045363  0.024573 -0.085736  0.356918  1.000000  0.197136
# fare        0.261963 -0.547617  0.098426  0.152367  0.197136  1.000000
# adult_male -0.531693  0.092699  0.195583 -0.233077 -0.300353 -0.175295
# alone      -0.155490  0.137372  0.099130 -0.619603 -0.543922 -0.260205
#
#             adult_male     alone
# survived     -0.531693 -0.155490
# pclass        0.092699  0.137372
# age           0.195583  0.099130
# sibsp        -0.233077 -0.619603
# parch        -0.300353 -0.543922
# fare         -0.175295 -0.260205
# adult_male    1.000000  0.341790
# alone         0.341790  1.000000

# %%
#Fase 3: Graficar
#Mataplotlib, pyplot
#import pandas as pd
import matplotlib.pyplot as plt

# %%
df.plot()
plt.show()

# %%
#Tipo grafica
df.plot(kind = "scatter", x="age", y="survived")
plt.show()

# %%
df["age"].plot(kind = "hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>
